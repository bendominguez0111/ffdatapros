# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/season2019week15.csv', index_col=0)

# %%
df.sort_values('FantasyPoints',ascending=False).head()
# Out:
#                   Player Pos   Tm  PassingYds  PassingTD  Int  PassingAtt  \
# 104          Julio Jones  WR  ATL           0          0    0           0
# 113         Kenyan Drake  RB  ARI           0          0    0           0
# 30   Christian McCaffrey  RB  CAR           0          0    0           1
# 118        Lamar Jackson  QB  BAL         212          5    0          23
# 136        Miles Sanders  RB  PHI           0          0    0           0
#
#      Cmp  Rec  Tgt  ReceivingYds  ReceivingTD  RushingAtt  RushingYds  \
# 104    0   13   20           134            2           0           0
# 113    0    0    0             0            0          22         137
# 30     0    8   10            88            0          19          87
# 118   15    0    0             0            0           8          86
# 136    0    6    6            50            1          19         122
#
#      RushingTD  FantasyPoints
# 104          0          38.40
# 113          4          37.70
# ...
